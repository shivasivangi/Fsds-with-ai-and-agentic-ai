# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
elephant_img=Image.open(r'C:\Users\SHIVA\Pictures\elephant.jpg')

# %%
elephant_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
type(elephant_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
Lion_img=Image.open(r'C:\Users\SHIVA\Pictures\Disney_The_Lion_King_2019.jpg')

# %%
Lion_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x326>
